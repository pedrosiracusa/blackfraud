# %%
from bs4 import BeautifulSoup
import requests
import numpy as np
import pandas as pd
import datetime

# %%
americanas_baseurl = "https://www.americanas.com.br"

# %%
# get categories from sitemap

AMERICANAS_BASEURL = "https://www.americanas.com.br"

def categoriesFromSitemap(sitemap_url):
    soup = BeautifulSoup(requests.get(sitemap_url).text, "html5lib")

    categories={}

    for cat in soup.find_all("li", {"class":"child-level-1"}):
        cat_a = cat.find("a")
        cat_name, cat_url = (cat_a.text, cat_a['href'])
        categories[cat_name] = {'url':cat_url, 'subcategories':{}}
        for subcat in cat.find_all("li",{"class":"child-level-2"}):
            subcat_a = subcat.find("a")
            subcat_name, subcat_url = (subcat_a.text, subcat_a['href'])
            categories[cat_name]['subcategories'][subcat_name] = subcat_url
    
    return categories


def getSubcategoriesUrls(categoriesDict):
    return [ url for cat,subcats in categoriesDict.items() for subcat,url in subcats['subcategories'].items() ]

# %%
def getProductData(productsPage_url, ordering='BestSellers', limit_num_offsets=None):
    print("Retrieving products from "+productsPage_url)
    productsPage = BeautifulSoup( requests.get(AMERICANAS_BASEURL+"/"+productsPage_url).text,"html5lib" )    

    products = []
    num_products = int(productsPage.find("aside",{'class':"sortbar"}).find("span").text.split()[0].replace('.',''))
    
     # these are url params that should be used for loading items pages
    limit = 24 # This is apparently hardcoded
    
    num_offsets = num_products//limit if num_products%limit==0 else (num_products//limit)+1
    
    if limit_num_offsets is not None: 
        num_offsets = min(limit_num_offsets,num_offsets)
    
    # Collects all products moving through offsets
    for offset in range(num_offsets):     

        print("  Collecting items from offset {} of {}".format(offset+1, num_offsets))

        requestUrl = AMERICANAS_BASEURL+"/"+productsPage_url+"?limite="+str(limit)+\
                                                             "&offset="+str(offset*limit)+\
                                                             "&ordenacao="+ordering
                
        productsGrid = BeautifulSoup( requests.get(requestUrl).text, "html5lib" )
        print("  ",format(requestUrl))        
        
        try:
            productItems = productsGrid.find("div",{'data-component':'productgrid'}).find_all("div",{'class':'product-grid-item'})
            # Retrieve data
            for i in productItems:
                try:
                    item = i.find("a")
                    item_title, item_code = (item['title'],item['href'].split("?")[0].split("/")[-1])
                    item_price = ' '.join( i.text for i in item.find_all("span",{'class':"value"}) )

                    try: item_discount = i.find("span",{'class':"label-discount-rate"}).text
                    except: item_discount=None

                    try: item_previous_price = item.find("del",{'class':"card-product-price-from-value"}).text
                    except: item_previous_price = None

                    try: item_rating = item.find("span",{'class':"rating-star-average"}).text
                    except: item_rating = None

                    try: item_num_ratings = item.find("div",{'class':"rating-star-counter"}).text[1]
                    except: item_num_ratings = None


                    products += [(item_code,
                                  item_title,
                                  item_price,
                                  item_previous_price, 
                                  item_discount,
                                  item_rating,
                                  item_num_ratings,
                                  productsPage_url,
                                  datetime.datetime.utcnow())]
                except:
                    pass

                
        except AttributeError:
            print("Offset ended before expected:",offset)
            break
            
    print("Done")        
    return products

# %%
import csv

def writeData(fpath, data):
    with open(fpath,'a') as fout:
        csv_out=csv.writer(fout)
        for row in data:
            csv_out.writerow(row)

# %% [markdown]
# ### Crawling for black friday promos

# %%
promos = [
    "hotsite/blackfriday-17/ate80",
    "hotsite/blackfriday-17/ate60",
    "hotsite/blackfriday-17/ate30",
    "hotsite/blackfriday-17/ate10"
]

# %%
# !rm descs.csv prices.csv ratings.csv

# %%
for promo in promos:
    
    prods = getProductData(promo)
    
    writeData('descs.csv',[ (p[0],p[1],p[8]) for p in prods ])
    writeData('prices.csv',[ (p[0],p[2],p[3],p[4],p[7],p[8]) for p in prods ])
    writeData('ratings.csv',[ (p[0],p[5],p[6]) for p in prods ])
# Out:
# Retrieving products from hotsite/blackfriday-17/ate80
#   Collecting items from offset 1 of 415
#    https://www.americanas.com.br/hotsite/blackfriday-17/ate80?limite=24&offset=0&ordenacao=BestSellers
#   Collecting items from offset 2 of 415
#    https://www.americanas.com.br/hotsite/blackfriday-17/ate80?limite=24&offset=24&ordenacao=BestSellers
#   Collecting items from offset 3 of 415
#    https://www.americanas.com.br/hotsite/blackfriday-17/ate80?limite=24&offset=48&ordenacao=BestSellers
#   Collecting items from offset 4 of 415
#    https://www.americanas.com.br/hotsite/blackfriday-17/ate80?limite=24&offset=72&ordenacao=BestSellers
#   Collecting items from offset 5 of 415
#    https://www.americanas.com.br/hotsite/blackfriday-17/ate80?limite=24&offset=96&ordenacao=BestSellers
#   Collecting items from offset 6 of 415
#    https://www.americanas.com.br/hotsite/blackfriday-17/ate80?limite=24&offset=120&ordenacao=BestSellers
#   Collecting items from offset 7 of 415
#    https://www.americanas.com.br/hotsite/blackfriday-17/ate80?limite=24&offset=144&ordenacao=BestSellers
#   Collecting items from offset 8 of 415
#    https://www.americanas.com.br/hotsite/blackfriday-17/ate80?limite=24&offset=168&ordenacao=BestSellers
#   Collecting items from offset 9 of 415
#    https://www.americanas.com.br/hotsite/blackfriday-17/ate80?limite=24&offset=192&ordenacao=BestSellers
#   Collecting items from offset 10 of 415
#    https://www.americanas.com.br/hotsite/blackfriday-17/ate80?limite=24&offset=216&ordenacao=BestSellers
#   Collecting items from offset 11 of 415
#    https://www.americanas.com.br/hotsite/blackfriday-17/ate80?limite=24&offset=240&ordenacao=BestSellers
#   Collecting items from offset 12 of 415
#    https://www.americanas.com.br/hotsite/blackfriday-17/ate80?limite=24&offset=264&ordenacao=BestSellers
#   Collecting items from offset 13 of 415
#    https://www.americanas.com.br/hotsite/blackfriday-17/ate80?limite=24&offset=288&ordenacao=BestSellers
#   Collecting items from offset 14 of 415
#    https://www.americanas.com.br/hotsite/blackfriday-17/ate80?limite=24&offset=312&ordenacao=BestSellers
#   Collecting items from offset 15 of 415
#    https://www.americanas.com.br/hotsite/blackfriday-17/ate80?limite=24&offset=336&ordenacao=BestSellers
#   Collecting items from offset 16 of 415
#    https://www.americanas.com.br/hotsite/blackfriday-17/ate80?limite=24&offset=360&ordenacao=BestSellers
#   Collecting items from offset 17 of 415
#    https://www.americanas.com.br/hotsite/blackfriday-17/ate80?limite=24&offset=384&ordenacao=BestSellers
#   Collecting items from offset 18 of 415
#    https://www.americanas.com.br/hotsite/blackfriday-17/ate80?limite=24&offset=408&ordenacao=BestSellers
#   Collecting items from offset 19 of 415
#    https://www.americanas.com.br/hotsite/blackfriday-17/ate80?limite=24&offset=432&ordenacao=BestSellers
#   Collecting items from offset 20 of 415
#    https://www.americanas.com.br/hotsite/blackfriday-17/ate80?limite=24&offset=456&ordenacao=BestSellers
#   Collecting items from offset 21 of 415
#    https://www.americanas.com.br/hotsite/blackfriday-17/ate80?limite=24&offset=480&ordenacao=BestSellers
#   Collecting items from offset 22 of 415
#    https://www.americanas.com.br/hotsite/blackfriday-17/ate80?limite=24&offset=504&ordenacao=BestSellers
#   Collecting items from offset 23 of 415
#    https://www.americanas.com.br/hotsite/blackfriday-17/ate80?limite=24&offset=528&ordenacao=BestSellers
#   Collecting items from offset 24 of 415
#    https://www.americanas.com.br/hotsite/blackfriday-17/ate80?limite=24&offset=552&ordenacao=BestSellers
#   Collecting items from offset 25 of 415
#    https://www.americanas.com.br/hotsite/blackfriday-17/ate80?limite=24&offset=576&ordenacao=BestSellers
#   Collecting items from offset 26 of 415
#    https://www.americanas.com.br/hotsite/blackfriday-17/ate80?limite=24&offset=600&ordenacao=BestSellers
#   Collecting items from offset 27 of 415
#    https://www.americanas.com.br/hotsite/blackfriday-17/ate80?limite=24&offset=624&ordenacao=BestSellers
#   Collecting items from offset 28 of 415
#    https://www.americanas.com.br/hotsite/blackfriday-17/ate80?limite=24&offset=648&ordenacao=BestSellers
#   Collecting items from offset 29 of 415
#    https://www.americanas.com.br/hotsite/blackfriday-17/ate80?limite=24&offset=672&ordenacao=BestSellers
#   Collecting items from offset 30 of 415
#    https://www.americanas.com.br/hotsite/blackfriday-17/ate80?limite=24&offset=696&ordenacao=BestSellers
#   Collecting items from offset 31 of 415
#    https://www.americanas.com.br/hotsite/blackfriday-17/ate80?limite=24&offset=720&ordenacao=BestSellers
#   Collecting items from offset 32 of 415
#    https://www.americanas.com.br/hotsite/blackfriday-17/ate80?limite=24&offset=744&ordenacao=BestSellers
#   Collecting items from offset 33 of 415
#    https://www.americanas.com.br/hotsite/blackfriday-17/ate80?limite=24&offset=768&ordenacao=BestSellers
#   Collecting items from offset 34 of 415
#    https://www.americanas.com.br/hotsite/blackfriday-17/ate80?limite=24&offset=792&ordenacao=BestSellers
#   Collecting items from offset 35 of 415
#    https://www.americanas.com.br/hotsite/blackfriday-17/ate80?limite=24&offset=816&ordenacao=BestSellers
#   Collecting items from offset 36 of 415
#    https://www.americanas.com.br/hotsite/blackfriday-17/ate80?limite=24&offset=840&ordenacao=BestSellers
#   Collecting items from offset 37 of 415
#    https://www.americanas.com.br/hotsite/blackfriday-17/ate80?limite=24&offset=864&ordenacao=BestSellers
#   Collecting items from offset 38 of 415
#    https://www.americanas.com.br/hotsite/blackfriday-17/ate80?limite=24&offset=888&ordenacao=BestSellers
#   Collecting items from offset 39 of 415
#    https://www.americanas.com.br/hotsite/blackfriday-17/ate80?limite=24&offset=912&ordenacao=BestSellers
#   Collecting items from offset 40 of 415
#    https://www.americanas.com.br/hotsite/blackfriday-17/ate80?limite=24&offset=936&ordenacao=BestSellers
#   Collecting items from offset 41 of 415
#    https://www.americanas.com.br/hotsite/blackfriday-17/ate80?limite=24&offset=960&ordenacao=BestSellers
#   Collecting items from offset 42 of 415
#    https://www.americanas.com.br/hotsite/blackfriday-17/ate80?limite=24&offset=984&ordenacao=BestSellers
#   Collecting items from offset 43 of 415
#    https://www.americanas.com.br/hotsite/blackfriday-17/ate80?limite=24&offset=1008&ordenacao=BestSellers
#   Collecting items from offset 44 of 415
#    https://www.americanas.com.br/hotsite/blackfriday-17/ate80?limite=24&offset=1032&ordenacao=BestSellers
#   Collecting items from offset 45 of 415
#    https://www.americanas.com.br/hotsite/blackfriday-17/ate80?limite=24&offset=1056&ordenacao=BestSellers
#   Collecting items from offset 46 of 415
#    https://www.americanas.com.br/hotsite/blackfriday-17/ate80?limite=24&offset=1080&ordenacao=BestSellers
#   Collecting items from offset 47 of 415
#    https://www.americanas.com.br/hotsite/blackfriday-17/ate80?limite=24&offset=1104&ordenacao=BestSellers
#   Collecting items from offset 48 of 415
#    https://www.americanas.com.br/hotsite/blackfriday-17/ate80?limite=24&offset=1128&ordenacao=BestSellers
#   Collecting items from offset 49 of 415
#    https://www.americanas.com.br/hotsite/blackfriday-17/ate80?limite=24&offset=1152&ordenacao=BestSellers
#   Collecting items from offset 50 of 415
#    https://www.americanas.com.br/hotsite/blackfriday-17/ate80?limite=24&offset=1176&ordenacao=BestSellers
#   Collecting items from offset 51 of 415
#    https://www.americanas.com.br/hotsite/blackfriday-17/ate80?limite=24&offset=1200&ordenacao=BestSellers
#   Collecting items from offset 52 of 415
#    https://www.americanas.com.br/hotsite/blackfriday-17/ate80?limite=24&offset=1224&ordenacao=BestSellers
#   Collecting items from offset 53 of 415
#    https://www.americanas.com.br/hotsite/blackfriday-17/ate80?limite=24&offset=1248&ordenacao=BestSellers
#   Collecting items from offset 54 of 415
#    https://www.americanas.com.br/hotsite/blackfriday-17/ate80?limite=24&offset=1272&ordenacao=BestSellers
#   Collecting items from offset 55 of 415
#    https://www.americanas.com.br/hotsite/blackfriday-17/ate80?limite=24&offset=1296&ordenacao=BestSellers
#   Collecting items from offset 56 of 415
#    https://www.americanas.com.br/hotsite/blackfriday-17/ate80?limite=24&offset=1320&ordenacao=BestSellers
#   Collecting items from offset 57 of 415
#    https://www.americanas.com.br/hotsite/blackfriday-17/ate80?limite=24&offset=1344&ordenacao=BestSellers
#   Collecting items from offset 58 of 415
#    https://www.americanas.com.br/hotsite/blackfriday-17/ate80?limite=24&offset=1368&ordenacao=BestSellers
#   Collecting items from offset 59 of 415
#    https://www.americanas.com.br/hotsite/blackfriday-17/ate80?limite=24&offset=1392&ordenacao=BestSellers
#   Collecting items from offset 60 of 415
#    https://www.americanas.com.br/hotsite/blackfriday-17/ate80?limite=24&offset=1416&ordenacao=BestSellers
#   Collecting items from offset 61 of 415
#    https://www.americanas.com.br/hotsite/blackfriday-17/ate80?limite=24&offset=1440&ordenacao=BestSellers
#   Collecting items from offset 62 of 415
#    https://www.americanas.com.br/hotsite/blackfriday-17/ate80?limite=24&offset=1464&ordenacao=BestSellers
#   Collecting items from offset 63 of 415
#    https://www.americanas.com.br/hotsite/blackfriday-17/ate80?limite=24&offset=1488&ordenacao=BestSellers
#   Collecting items from offset 64 of 415
#    https://www.americanas.com.br/hotsite/blackfriday-17/ate80?limite=24&offset=1512&ordenacao=BestSellers
#   Collecting items from offset 65 of 415
#    https://www.americanas.com.br/hotsite/blackfriday-17/ate80?limite=24&offset=1536&ordenacao=BestSellers
#   Collecting items from offset 66 of 415
#    https://www.americanas.com.br/hotsite/blackfriday-17/ate80?limite=24&offset=1560&ordenacao=BestSellers
#   Collecting items from offset 67 of 415
#    https://www.americanas.com.br/hotsite/blackfriday-17/ate80?limite=24&offset=1584&ordenacao=BestSellers
#   Collecting items from offset 68 of 415
#    https://www.americanas.com.br/hotsite/blackfriday-17/ate80?limite=24&offset=1608&ordenacao=BestSellers
#   Collecting items from offset 69 of 415
#    https://www.americanas.com.br/hotsite/blackfriday-17/ate80?limite=24&offset=1632&ordenacao=BestSellers
#   Collecting items from offset 70 of 415
#    https://www.americanas.com.br/hotsite/blackfriday-17/ate80?limite=24&offset=1656&ordenacao=BestSellers
#   Collecting items from offset 71 of 415
#    https://www.americanas.com.br/hotsite/blackfriday-17/ate80?limite=24&offset=1680&ordenacao=BestSellers
#   Collecting items from offset 72 of 415
#    https://www.americanas.com.br/hotsite/blackfriday-17/ate80?limite=24&offset=1704&ordenacao=BestSellers
# Offset ended before expected: 71
# Done
# Retrieving products from hotsite/blackfriday-17/ate60
#   Collecting items from offset 1 of 3298
#    https://www.americanas.com.br/hotsite/blackfriday-17/ate60?limite=24&offset=0&ordenacao=BestSellers
#   Collecting items from offset 2 of 3298
#    https://www.americanas.com.br/hotsite/blackfriday-17/ate60?limite=24&offset=24&ordenacao=BestSellers
#   Collecting items from offset 3 of 3298
#    https://www.americanas.com.br/hotsite/blackfriday-17/ate60?limite=24&offset=48&ordenacao=BestSellers
#   Collecting items from offset 4 of 3298
#    https://www.americanas.com.br/hotsite/blackfriday-17/ate60?limite=24&offset=72&ordenacao=BestSellers
#   Collecting items from offset 5 of 3298
#    https://www.americanas.com.br/hotsite/blackfriday-17/ate60?limite=24&offset=96&ordenacao=BestSellers
#   Collecting items from offset 6 of 3298
#    https://www.americanas.com.br/hotsite/blackfriday-17/ate60?limite=24&offset=120&ordenacao=BestSellers
#   Collecting items from offset 7 of 3298
#    https://www.americanas.com.br/hotsite/blackfriday-17/ate60?limite=24&offset=144&ordenacao=BestSellers
#   Collecting items from offset 8 of 3298
#    https://www.americanas.com.br/hotsite/blackfriday-17/ate60?limite=24&offset=168&ordenacao=BestSellers
#   Collecting items from offset 9 of 3298
#    https://www.americanas.com.br/hotsite/blackfriday-17/ate60?limite=24&offset=192&ordenacao=BestSellers
#   Collecting items from offset 10 of 3298
#    https://www.americanas.com.br/hotsite/blackfriday-17/ate60?limite=24&offset=216&ordenacao=BestSellers
#   Collecting items from offset 11 of 3298
#    https://www.americanas.com.br/hotsite/blackfriday-17/ate60?limite=24&offset=240&ordenacao=BestSellers
#   Collecting items from offset 12 of 3298
#    https://www.americanas.com.br/hotsite/blackfriday-17/ate60?limite=24&offset=264&ordenacao=BestSellers
#   Collecting items from offset 13 of 3298
#    https://www.americanas.com.br/hotsite/blackfriday-17/ate60?limite=24&offset=288&ordenacao=BestSellers
#   Collecting items from offset 14 of 3298
#    https://www.americanas.com.br/hotsite/blackfriday-17/ate60?limite=24&offset=312&ordenacao=BestSellers
#   Collecting items from offset 15 of 3298
#    https://www.americanas.com.br/hotsite/blackfriday-17/ate60?limite=24&offset=336&ordenacao=BestSellers
#   Collecting items from offset 16 of 3298
#    https://www.americanas.com.br/hotsite/blackfriday-17/ate60?limite=24&offset=360&ordenacao=BestSellers
#   Collecting items from offset 17 of 3298
#    https://www.americanas.com.br/hotsite/blackfriday-17/ate60?limite=24&offset=384&ordenacao=BestSellers
#   Collecting items from offset 18 of 3298
#    https://www.americanas.com.br/hotsite/blackfriday-17/ate60?limite=24&offset=408&ordenacao=BestSellers
#   Collecting items from offset 19 of 3298
#    https://www.americanas.com.br/hotsite/blackfriday-17/ate60?limite=24&offset=432&ordenacao=BestSellers
#   Collecting items from offset 20 of 3298
#    https://www.americanas.com.br/hotsite/blackfriday-17/ate60?limite=24&offset=456&ordenacao=BestSellers
#   Collecting items from offset 21 of 3298
#    https://www.americanas.com.br/hotsite/blackfriday-17/ate60?limite=24&offset=480&ordenacao=BestSellers
#   Collecting items from offset 22 of 3298
#    https://www.americanas.com.br/hotsite/blackfriday-17/ate60?limite=24&offset=504&ordenacao=BestSellers
#   Collecting items from offset 23 of 3298
#    https://www.americanas.com.br/hotsite/blackfriday-17/ate60?limite=24&offset=528&ordenacao=BestSellers
#   Collecting items from offset 24 of 3298
#    https://www.americanas.com.br/hotsite/blackfriday-17/ate60?limite=24&offset=552&ordenacao=BestSellers
#   Collecting items from offset 25 of 3298
#    https://www.americanas.com.br/hotsite/blackfriday-17/ate60?limite=24&offset=576&ordenacao=BestSellers
#   Collecting items from offset 26 of 3298
#    https://www.americanas.com.br/hotsite/blackfriday-17/ate60?limite=24&offset=600&ordenacao=BestSellers
#   Collecting items from offset 27 of 3298
#    https://www.americanas.com.br/hotsite/blackfriday-17/ate60?limite=24&offset=624&ordenacao=BestSellers
#   Collecting items from offset 28 of 3298
#    https://www.americanas.com.br/hotsite/blackfriday-17/ate60?limite=24&offset=648&ordenacao=BestSellers
#   Collecting items from offset 29 of 3298
#    https://www.americanas.com.br/hotsite/blackfriday-17/ate60?limite=24&offset=672&ordenacao=BestSellers
#   Collecting items from offset 30 of 3298
#    https://www.americanas.com.br/hotsite/blackfriday-17/ate60?limite=24&offset=696&ordenacao=BestSellers
#   Collecting items from offset 31 of 3298
#    https://www.americanas.com.br/hotsite/blackfriday-17/ate60?limite=24&offset=720&ordenacao=BestSellers
#   Collecting items from offset 32 of 3298
#    https://www.americanas.com.br/hotsite/blackfriday-17/ate60?limite=24&offset=744&ordenacao=BestSellers
#   Collecting items from offset 33 of 3298
#    https://www.americanas.com.br/hotsite/blackfriday-17/ate60?limite=24&offset=768&ordenacao=BestSellers
#   Collecting items from offset 34 of 3298
#    https://www.americanas.com.br/hotsite/blackfriday-17/ate60?limite=24&offset=792&ordenacao=BestSellers
#   Collecting items from offset 35 of 3298
#    https://www.americanas.com.br/hotsite/blackfriday-17/ate60?limite=24&offset=816&ordenacao=BestSellers
#   Collecting items from offset 36 of 3298
#    https://www.americanas.com.br/hotsite/blackfriday-17/ate60?limite=24&offset=840&ordenacao=BestSellers
#   Collecting items from offset 37 of 3298
#    https://www.americanas.com.br/hotsite/blackfriday-17/ate60?limite=24&offset=864&ordenacao=BestSellers
#   Collecting items from offset 38 of 3298
#    https://www.americanas.com.br/hotsite/blackfriday-17/ate60?limite=24&offset=888&ordenacao=BestSellers
# Offset ended before expected: 37
# Done
# Retrieving products from hotsite/blackfriday-17/ate30
#   Collecting items from offset 1 of 11615
#    https://www.americanas.com.br/hotsite/blackfriday-17/ate30?limite=24&offset=0&ordenacao=BestSellers
#   Collecting items from offset 2 of 11615
#    https://www.americanas.com.br/hotsite/blackfriday-17/ate30?limite=24&offset=24&ordenacao=BestSellers
#   Collecting items from offset 3 of 11615
#    https://www.americanas.com.br/hotsite/blackfriday-17/ate30?limite=24&offset=48&ordenacao=BestSellers
# Offset ended before expected: 2
# Done
# Retrieving products from hotsite/blackfriday-17/ate10
#   Collecting items from offset 1 of 9083
#    https://www.americanas.com.br/hotsite/blackfriday-17/ate10?limite=24&offset=0&ordenacao=BestSellers
#   Collecting items from offset 2 of 9083
#    https://www.americanas.com.br/hotsite/blackfriday-17/ate10?limite=24&offset=24&ordenacao=BestSellers
#   Collecting items from offset 3 of 9083
#    https://www.americanas.com.br/hotsite/blackfriday-17/ate10?limite=24&offset=48&ordenacao=BestSellers
#   Collecting items from offset 4 of 9083
#    https://www.americanas.com.br/hotsite/blackfriday-17/ate10?limite=24&offset=72&ordenacao=BestSellers
#   Collecting items from offset 5 of 9083
#    https://www.americanas.com.br/hotsite/blackfriday-17/ate10?limite=24&offset=96&ordenacao=BestSellers
#   Collecting items from offset 6 of 9083
#    https://www.americanas.com.br/hotsite/blackfriday-17/ate10?limite=24&offset=120&ordenacao=BestSellers
#   Collecting items from offset 7 of 9083
#    https://www.americanas.com.br/hotsite/blackfriday-17/ate10?limite=24&offset=144&ordenacao=BestSellers
#   Collecting items from offset 8 of 9083
#    https://www.americanas.com.br/hotsite/blackfriday-17/ate10?limite=24&offset=168&ordenacao=BestSellers
#   Collecting items from offset 9 of 9083
#    https://www.americanas.com.br/hotsite/blackfriday-17/ate10?limite=24&offset=192&ordenacao=BestSellers
#   Collecting items from offset 10 of 9083
#    https://www.americanas.com.br/hotsite/blackfriday-17/ate10?limite=24&offset=216&ordenacao=BestSellers
#   Collecting items from offset 11 of 9083
#    https://www.americanas.com.br/hotsite/blackfriday-17/ate10?limite=24&offset=240&ordenacao=BestSellers
#   Collecting items from offset 12 of 9083
#    https://www.americanas.com.br/hotsite/blackfriday-17/ate10?limite=24&offset=264&ordenacao=BestSellers
#   Collecting items from offset 13 of 9083
#    https://www.americanas.com.br/hotsite/blackfriday-17/ate10?limite=24&offset=288&ordenacao=BestSellers
# Offset ended before expected: 12
# Done

# %%
# Read data
descs = pd.read_csv('./sunday_descs.csv',header=None, 
                   names=['Product Id','Title', 'Datetime Crawled'])

prices = pd.read_csv('./sunday_prices.csv',header=None,
                     names=['Product Id','Price','Previous Price', 'Discount','Promo','Datetime Crawled'])

prices.set_index('Product Id', inplace=True)
descs.set_index('Product Id', inplace=True)

# Get percentage discount
prices['Discount'] = prices['Discount'].apply( lambda x: x if x is np.NaN else float(x.split("%")[0])/100 )

# Reformat prices data
getPrice = lambda x: x if x is np.NaN else float(x.split("R$")[1].replace('.','').replace(',','.'))
prices['Price'] = prices['Price'].apply(getPrice)
prices['Previous Price'] = prices['Previous Price'].apply(getPrice)

prices['Previous Price Inferred'] = prices['Price']/(1-prices['Discount'])

# Join tables
prods = descs[['Title']].join(prices)

# %%
prods['Product Id'] = prods.index

# %%
prods.drop_duplicates(subset=['Product Id','Title','Price','Discount'],inplace=True)

# %%
prods.index.is_unique
# Out:
# False

# %%
prods[prods.index.duplicated()]
# Out:
#                                                  Title  Price  Previous Price  \
# Product Id
# 114005310   Livro - Manual de Instrumentação Cirúrgica   18.0             NaN
#
#             Discount                         Promo  \
# Product Id
# 114005310       0.82  hotsite/blackfriday-17/ate80
#
#                       Datetime Crawled  Previous Price Inferred  Product Id
# Product Id
# 114005310   2017-11-26 14:49:56.836041                    100.0   114005310

# %%
prods.loc[114005310]
# Out:
#                                                  Title  Price  Previous Price  \
# Product Id
# 114005310   Livro - Manual de Instrumentação Cirúrgica  23.99           103.0
# 114005310   Livro - Manual de Instrumentação Cirúrgica  18.00             NaN
#
#             Discount                         Promo  \
# Product Id
# 114005310       0.76  hotsite/blackfriday-17/ate80
# 114005310       0.82  hotsite/blackfriday-17/ate80
#
#                       Datetime Crawled  Previous Price Inferred  Product Id
# Product Id
# 114005310   2017-11-26 14:49:27.375357                99.958333   114005310
# 114005310   2017-11-26 14:49:56.836041               100.000000   114005310

# %% [markdown]
# ### Crawling for Cyber Monday promos

# %%
promos = [
    "hotsite/cyber/ate80",
    "hotsite/cyber/ate60",
    "hotsite/cyber/ate30",
    "hotsite/cyber/ate10"
]

for promo in promos:
    
    prods = getProductData(promo,limit_num_offsets=100)
    
    writeData('descs.csv',[ (p[0],p[1],p[8]) for p in prods ])
    writeData('prices.csv',[ (p[0],p[2],p[3],p[4],p[7],p[8]) for p in prods ])
    writeData('ratings.csv',[ (p[0],p[5],p[6]) for p in prods ])
# Out:
# Retrieving products from hotsite/cyber/ate80
#   Collecting items from offset 1 of 100
#    https://www.americanas.com.br/hotsite/cyber/ate80?limite=24&offset=0&ordenacao=BestSellers
#   Collecting items from offset 2 of 100
#    https://www.americanas.com.br/hotsite/cyber/ate80?limite=24&offset=24&ordenacao=BestSellers
#   Collecting items from offset 3 of 100
#    https://www.americanas.com.br/hotsite/cyber/ate80?limite=24&offset=48&ordenacao=BestSellers
#   Collecting items from offset 4 of 100
#    https://www.americanas.com.br/hotsite/cyber/ate80?limite=24&offset=72&ordenacao=BestSellers
#   Collecting items from offset 5 of 100
#    https://www.americanas.com.br/hotsite/cyber/ate80?limite=24&offset=96&ordenacao=BestSellers
#   Collecting items from offset 6 of 100
#    https://www.americanas.com.br/hotsite/cyber/ate80?limite=24&offset=120&ordenacao=BestSellers
#   Collecting items from offset 7 of 100
#    https://www.americanas.com.br/hotsite/cyber/ate80?limite=24&offset=144&ordenacao=BestSellers
#   Collecting items from offset 8 of 100
#    https://www.americanas.com.br/hotsite/cyber/ate80?limite=24&offset=168&ordenacao=BestSellers
#   Collecting items from offset 9 of 100
#    https://www.americanas.com.br/hotsite/cyber/ate80?limite=24&offset=192&ordenacao=BestSellers
#   Collecting items from offset 10 of 100
#    https://www.americanas.com.br/hotsite/cyber/ate80?limite=24&offset=216&ordenacao=BestSellers
#   Collecting items from offset 11 of 100
#    https://www.americanas.com.br/hotsite/cyber/ate80?limite=24&offset=240&ordenacao=BestSellers
#   Collecting items from offset 12 of 100
#    https://www.americanas.com.br/hotsite/cyber/ate80?limite=24&offset=264&ordenacao=BestSellers
#   Collecting items from offset 13 of 100
#    https://www.americanas.com.br/hotsite/cyber/ate80?limite=24&offset=288&ordenacao=BestSellers
#   Collecting items from offset 14 of 100
#    https://www.americanas.com.br/hotsite/cyber/ate80?limite=24&offset=312&ordenacao=BestSellers
#   Collecting items from offset 15 of 100
#    https://www.americanas.com.br/hotsite/cyber/ate80?limite=24&offset=336&ordenacao=BestSellers
#   Collecting items from offset 16 of 100
#    https://www.americanas.com.br/hotsite/cyber/ate80?limite=24&offset=360&ordenacao=BestSellers
#   Collecting items from offset 17 of 100
#    https://www.americanas.com.br/hotsite/cyber/ate80?limite=24&offset=384&ordenacao=BestSellers
#   Collecting items from offset 18 of 100
#    https://www.americanas.com.br/hotsite/cyber/ate80?limite=24&offset=408&ordenacao=BestSellers
#   Collecting items from offset 19 of 100
#    https://www.americanas.com.br/hotsite/cyber/ate80?limite=24&offset=432&ordenacao=BestSellers
#   Collecting items from offset 20 of 100
#    https://www.americanas.com.br/hotsite/cyber/ate80?limite=24&offset=456&ordenacao=BestSellers
#   Collecting items from offset 21 of 100
#    https://www.americanas.com.br/hotsite/cyber/ate80?limite=24&offset=480&ordenacao=BestSellers
#   Collecting items from offset 22 of 100
#    https://www.americanas.com.br/hotsite/cyber/ate80?limite=24&offset=504&ordenacao=BestSellers
#   Collecting items from offset 23 of 100
#    https://www.americanas.com.br/hotsite/cyber/ate80?limite=24&offset=528&ordenacao=BestSellers
#   Collecting items from offset 24 of 100
#    https://www.americanas.com.br/hotsite/cyber/ate80?limite=24&offset=552&ordenacao=BestSellers
#   Collecting items from offset 25 of 100
#    https://www.americanas.com.br/hotsite/cyber/ate80?limite=24&offset=576&ordenacao=BestSellers
#   Collecting items from offset 26 of 100
#    https://www.americanas.com.br/hotsite/cyber/ate80?limite=24&offset=600&ordenacao=BestSellers
#   Collecting items from offset 27 of 100
#    https://www.americanas.com.br/hotsite/cyber/ate80?limite=24&offset=624&ordenacao=BestSellers
#   Collecting items from offset 28 of 100
#    https://www.americanas.com.br/hotsite/cyber/ate80?limite=24&offset=648&ordenacao=BestSellers
#   Collecting items from offset 29 of 100
#    https://www.americanas.com.br/hotsite/cyber/ate80?limite=24&offset=672&ordenacao=BestSellers
#   Collecting items from offset 30 of 100
#    https://www.americanas.com.br/hotsite/cyber/ate80?limite=24&offset=696&ordenacao=BestSellers
#   Collecting items from offset 31 of 100
#    https://www.americanas.com.br/hotsite/cyber/ate80?limite=24&offset=720&ordenacao=BestSellers
#   Collecting items from offset 32 of 100
#    https://www.americanas.com.br/hotsite/cyber/ate80?limite=24&offset=744&ordenacao=BestSellers
#   Collecting items from offset 33 of 100
#    https://www.americanas.com.br/hotsite/cyber/ate80?limite=24&offset=768&ordenacao=BestSellers
#   Collecting items from offset 34 of 100
#    https://www.americanas.com.br/hotsite/cyber/ate80?limite=24&offset=792&ordenacao=BestSellers
# Offset ended before expected: 33
# Done
# Retrieving products from hotsite/cyber/ate60
#   Collecting items from offset 1 of 100
#    https://www.americanas.com.br/hotsite/cyber/ate60?limite=24&offset=0&ordenacao=BestSellers
#   Collecting items from offset 2 of 100
#    https://www.americanas.com.br/hotsite/cyber/ate60?limite=24&offset=24&ordenacao=BestSellers
#   Collecting items from offset 3 of 100
#    https://www.americanas.com.br/hotsite/cyber/ate60?limite=24&offset=48&ordenacao=BestSellers
#   Collecting items from offset 4 of 100
#    https://www.americanas.com.br/hotsite/cyber/ate60?limite=24&offset=72&ordenacao=BestSellers
#   Collecting items from offset 5 of 100
#    https://www.americanas.com.br/hotsite/cyber/ate60?limite=24&offset=96&ordenacao=BestSellers
#   Collecting items from offset 6 of 100
#    https://www.americanas.com.br/hotsite/cyber/ate60?limite=24&offset=120&ordenacao=BestSellers
#   Collecting items from offset 7 of 100
#    https://www.americanas.com.br/hotsite/cyber/ate60?limite=24&offset=144&ordenacao=BestSellers
#   Collecting items from offset 8 of 100
#    https://www.americanas.com.br/hotsite/cyber/ate60?limite=24&offset=168&ordenacao=BestSellers
#   Collecting items from offset 9 of 100
#    https://www.americanas.com.br/hotsite/cyber/ate60?limite=24&offset=192&ordenacao=BestSellers
#   Collecting items from offset 10 of 100
#    https://www.americanas.com.br/hotsite/cyber/ate60?limite=24&offset=216&ordenacao=BestSellers
#   Collecting items from offset 11 of 100
#    https://www.americanas.com.br/hotsite/cyber/ate60?limite=24&offset=240&ordenacao=BestSellers
#   Collecting items from offset 12 of 100
#    https://www.americanas.com.br/hotsite/cyber/ate60?limite=24&offset=264&ordenacao=BestSellers
#   Collecting items from offset 13 of 100
#    https://www.americanas.com.br/hotsite/cyber/ate60?limite=24&offset=288&ordenacao=BestSellers
#   Collecting items from offset 14 of 100
#    https://www.americanas.com.br/hotsite/cyber/ate60?limite=24&offset=312&ordenacao=BestSellers
#   Collecting items from offset 15 of 100
#    https://www.americanas.com.br/hotsite/cyber/ate60?limite=24&offset=336&ordenacao=BestSellers
#   Collecting items from offset 16 of 100
#    https://www.americanas.com.br/hotsite/cyber/ate60?limite=24&offset=360&ordenacao=BestSellers
#   Collecting items from offset 17 of 100
#    https://www.americanas.com.br/hotsite/cyber/ate60?limite=24&offset=384&ordenacao=BestSellers
#   Collecting items from offset 18 of 100
#    https://www.americanas.com.br/hotsite/cyber/ate60?limite=24&offset=408&ordenacao=BestSellers
#   Collecting items from offset 19 of 100
#    https://www.americanas.com.br/hotsite/cyber/ate60?limite=24&offset=432&ordenacao=BestSellers
#   Collecting items from offset 20 of 100
#    https://www.americanas.com.br/hotsite/cyber/ate60?limite=24&offset=456&ordenacao=BestSellers
#   Collecting items from offset 21 of 100
#    https://www.americanas.com.br/hotsite/cyber/ate60?limite=24&offset=480&ordenacao=BestSellers
# Offset ended before expected: 20
# Done
# Retrieving products from hotsite/cyber/ate30
#   Collecting items from offset 1 of 100
#    https://www.americanas.com.br/hotsite/cyber/ate30?limite=24&offset=0&ordenacao=BestSellers
#   Collecting items from offset 2 of 100
#    https://www.americanas.com.br/hotsite/cyber/ate30?limite=24&offset=24&ordenacao=BestSellers
#   Collecting items from offset 3 of 100
#    https://www.americanas.com.br/hotsite/cyber/ate30?limite=24&offset=48&ordenacao=BestSellers
#   Collecting items from offset 4 of 100
#    https://www.americanas.com.br/hotsite/cyber/ate30?limite=24&offset=72&ordenacao=BestSellers
#   Collecting items from offset 5 of 100
#    https://www.americanas.com.br/hotsite/cyber/ate30?limite=24&offset=96&ordenacao=BestSellers
#   Collecting items from offset 6 of 100
#    https://www.americanas.com.br/hotsite/cyber/ate30?limite=24&offset=120&ordenacao=BestSellers
#   Collecting items from offset 7 of 100
#    https://www.americanas.com.br/hotsite/cyber/ate30?limite=24&offset=144&ordenacao=BestSellers
#   Collecting items from offset 8 of 100
#    https://www.americanas.com.br/hotsite/cyber/ate30?limite=24&offset=168&ordenacao=BestSellers
#   Collecting items from offset 9 of 100
#    https://www.americanas.com.br/hotsite/cyber/ate30?limite=24&offset=192&ordenacao=BestSellers
#   Collecting items from offset 10 of 100
#    https://www.americanas.com.br/hotsite/cyber/ate30?limite=24&offset=216&ordenacao=BestSellers
#   Collecting items from offset 11 of 100
#    https://www.americanas.com.br/hotsite/cyber/ate30?limite=24&offset=240&ordenacao=BestSellers
# Offset ended before expected: 10
# Done
# Retrieving products from hotsite/cyber/ate10
#   Collecting items from offset 1 of 100
#    https://www.americanas.com.br/hotsite/cyber/ate10?limite=24&offset=0&ordenacao=BestSellers
#   Collecting items from offset 2 of 100
#    https://www.americanas.com.br/hotsite/cyber/ate10?limite=24&offset=24&ordenacao=BestSellers
#   Collecting items from offset 3 of 100
#    https://www.americanas.com.br/hotsite/cyber/ate10?limite=24&offset=48&ordenacao=BestSellers
#   Collecting items from offset 4 of 100
#    https://www.americanas.com.br/hotsite/cyber/ate10?limite=24&offset=72&ordenacao=BestSellers
#   Collecting items from offset 5 of 100
#    https://www.americanas.com.br/hotsite/cyber/ate10?limite=24&offset=96&ordenacao=BestSellers
#   Collecting items from offset 6 of 100
#    https://www.americanas.com.br/hotsite/cyber/ate10?limite=24&offset=120&ordenacao=BestSellers
#   Collecting items from offset 7 of 100
#    https://www.americanas.com.br/hotsite/cyber/ate10?limite=24&offset=144&ordenacao=BestSellers
#   Collecting items from offset 8 of 100
#    https://www.americanas.com.br/hotsite/cyber/ate10?limite=24&offset=168&ordenacao=BestSellers
#   Collecting items from offset 9 of 100
#    https://www.americanas.com.br/hotsite/cyber/ate10?limite=24&offset=192&ordenacao=BestSellers
#   Collecting items from offset 10 of 100
#    https://www.americanas.com.br/hotsite/cyber/ate10?limite=24&offset=216&ordenacao=BestSellers
#   Collecting items from offset 11 of 100
#    https://www.americanas.com.br/hotsite/cyber/ate10?limite=24&offset=240&ordenacao=BestSellers
#   Collecting items from offset 12 of 100
#    https://www.americanas.com.br/hotsite/cyber/ate10?limite=24&offset=264&ordenacao=BestSellers
#   Collecting items from offset 13 of 100
#    https://www.americanas.com.br/hotsite/cyber/ate10?limite=24&offset=288&ordenacao=BestSellers
#   Collecting items from offset 14 of 100
#    https://www.americanas.com.br/hotsite/cyber/ate10?limite=24&offset=312&ordenacao=BestSellers
#   Collecting items from offset 15 of 100
#    https://www.americanas.com.br/hotsite/cyber/ate10?limite=24&offset=336&ordenacao=BestSellers
#   Collecting items from offset 16 of 100
#    https://www.americanas.com.br/hotsite/cyber/ate10?limite=24&offset=360&ordenacao=BestSellers
#   Collecting items from offset 17 of 100
#    https://www.americanas.com.br/hotsite/cyber/ate10?limite=24&offset=384&ordenacao=BestSellers
#   Collecting items from offset 18 of 100
#    https://www.americanas.com.br/hotsite/cyber/ate10?limite=24&offset=408&ordenacao=BestSellers
#   Collecting items from offset 19 of 100
#    https://www.americanas.com.br/hotsite/cyber/ate10?limite=24&offset=432&ordenacao=BestSellers
#   Collecting items from offset 20 of 100
#    https://www.americanas.com.br/hotsite/cyber/ate10?limite=24&offset=456&ordenacao=BestSellers
#   Collecting items from offset 21 of 100
#    https://www.americanas.com.br/hotsite/cyber/ate10?limite=24&offset=480&ordenacao=BestSellers
#   Collecting items from offset 22 of 100
#    https://www.americanas.com.br/hotsite/cyber/ate10?limite=24&offset=504&ordenacao=BestSellers
#   Collecting items from offset 23 of 100
#    https://www.americanas.com.br/hotsite/cyber/ate10?limite=24&offset=528&ordenacao=BestSellers
#   Collecting items from offset 24 of 100
#    https://www.americanas.com.br/hotsite/cyber/ate10?limite=24&offset=552&ordenacao=BestSellers
#   Collecting items from offset 25 of 100
#    https://www.americanas.com.br/hotsite/cyber/ate10?limite=24&offset=576&ordenacao=BestSellers
#   Collecting items from offset 26 of 100
#    https://www.americanas.com.br/hotsite/cyber/ate10?limite=24&offset=600&ordenacao=BestSellers
#   Collecting items from offset 27 of 100
#    https://www.americanas.com.br/hotsite/cyber/ate10?limite=24&offset=624&ordenacao=BestSellers
#   Collecting items from offset 28 of 100
#    https://www.americanas.com.br/hotsite/cyber/ate10?limite=24&offset=648&ordenacao=BestSellers
#   Collecting items from offset 29 of 100
#    https://www.americanas.com.br/hotsite/cyber/ate10?limite=24&offset=672&ordenacao=BestSellers
#   Collecting items from offset 30 of 100
#    https://www.americanas.com.br/hotsite/cyber/ate10?limite=24&offset=696&ordenacao=BestSellers
#   Collecting items from offset 31 of 100
#    https://www.americanas.com.br/hotsite/cyber/ate10?limite=24&offset=720&ordenacao=BestSellers
#   Collecting items from offset 32 of 100
#    https://www.americanas.com.br/hotsite/cyber/ate10?limite=24&offset=744&ordenacao=BestSellers
#   Collecting items from offset 33 of 100
#    https://www.americanas.com.br/hotsite/cyber/ate10?limite=24&offset=768&ordenacao=BestSellers
#   Collecting items from offset 34 of 100
#    https://www.americanas.com.br/hotsite/cyber/ate10?limite=24&offset=792&ordenacao=BestSellers
#   Collecting items from offset 35 of 100
#    https://www.americanas.com.br/hotsite/cyber/ate10?limite=24&offset=816&ordenacao=BestSellers
# Offset ended before expected: 34
# Done

# %% [markdown]
# ---

# %% [markdown]
# ## Working with the scraped data

# %%
descs_cyber = pd.read_csv('cyber_descs.csv',header=None,
                    names=['Product Id','Title', 'Datetime Crawled'])

prices_cyber = pd.read_csv('cyber_prices.csv',header=None,
                    names=['Product Id','Price','Previous Price', 'Discount','Promo','Datetime Crawled'])

descs_bf = pd.read_csv('./sunday_descs.csv',header=None, 
                   names=['Product Id','Title', 'Datetime Crawled'])

prices_bf = pd.read_csv('./sunday_prices.csv',header=None,
                     names=['Product Id','Price','Previous Price', 'Discount','Promo','Datetime Crawled'])

prices_cyber.set_index('Product Id', inplace=True, drop=False)
descs_cyber.set_index('Product Id', inplace=True, drop=False)
prices_bf.set_index('Product Id', inplace=True, drop=False)
descs_bf.set_index('Product Id', inplace=True, drop=False)

# %%
# Concatenate products tables and drop duplicates
prod_descs = pd.concat([descs_bf,descs_cyber]).drop_duplicates(subset=['Product Id','Title'])

# %%
prod_descs.shape
# Out:
# (3124, 3)

# %%
prod_descs.head()
# Out:
#             Product Id                                              Title  \
# Product Id
# 128442334    128442334  Passadeira Compacta à Vapor Cadence Lisser Pro...
# 25660057      25660057  Furadeira impacto 1/2 Songhe Tools 550W 110V m...
# 20813260      20813260  Computador Desktop EasyPC Intel Core i5 8GB HD...
# 16064504      16064504  Relógio De Pulso Invicta 0074 Pro Diver Chrono...
# 11234730      11234730  Dvr Stand Alone Tríbrido Hdcvi Intelbras Hdcvi...
#
#                       Datetime Crawled
# Product Id
# 128442334   2017-11-26 14:49:20.281974
# 25660057    2017-11-26 14:49:20.283970
# 20813260    2017-11-26 14:49:20.285879
# 16064504    2017-11-26 14:49:20.287835
# 11234730    2017-11-26 14:49:20.289721

# %%
df1 = prod_descs[['Title']].join(prices_bf,how='right')
df2 = prod_descs[['Title']].join(prices_cyber,how='right')

prod = pd.concat([df1,df2])

# Get percentage discount
prod['Discount'] = prod['Discount'].apply( lambda x: x if x is np.NaN else float(x.split("%")[0])/100 )

# Reformat prices data
getPrice = lambda x: x if x is np.NaN else float(x.split("R$")[1].replace('.','').replace(',','.'))
prod['Price'] = prod['Price'].apply(getPrice)
prod['Previous Price'] = prod['Previous Price'].apply(getPrice)

prod['Previous Price Inferred'] = prod['Price']/(1-prod['Discount'])

# %%
prod.drop_duplicates(subset=['Price','Previous Price','Discount','Promo'],inplace=True)

# %%
prod.shape
# Out:
# (3830, 8)

# %%
prod.head()
# Out:
#                                                         Title  Product Id  \
# Product Id
# 148534      Frigobar c/ Porta de Vidro BZA08 76L Preto - B...      148534
# 167862                                 Livro - Faça Dar Certo      167862
# 198697                                     Massagem da Cabeça      198697
# 228073                                            DVD Solaris      228073
# 228139         Box DVD Coleção Friends: 3ª Temporada (4 DVDs)      228139
#
#               Price  Previous Price  Discount                         Promo  \
# Product Id
# 18249946    Amortecedor Palio 01/ 11 Kit 4 Amortecedores+2...    18249946
# 124656706   Cafeteira Tramontina by Breville Express Pro 2...   124656706
# 116923261        Aparelho de Barbear Gillette Proglide Styler   116923261
# 18639777    Conjunto De Talheres P/ Churrasco 12 Peças - T...    18639777
# 15001186           Aparelho de Jantar 42 Peças Ipanema - Zeex    15001186
# 18765754    Guarda-roupa Casal 3 Portas Com Espelho Campos...    18765754
# 22547223    Ar Condicionado Split Piso Teto On/off Carrier...    22547223
# 26881115    Kit 3 Malas De Viagem Jogo Conjunto Pequena Mé...    26881115
# 13988734    Aquecedor Á Gás Modelo Lz 1600 N Glp Da Lorenz...    13988734
# 21081126    Quarto Modulado Casal Módena 7 Peças Composiçã...    21081126
# 20489380    Guarda-Roupa Casal em MDF Paris 6 Portas Maxel...    20489380
# 17301722    Computador Intel Dual Core 2.41ghz 4gb Hd 1tb ...    17301722
# 22811920    Cadeira Auto Galzerano Flyn de 9 a 25Kg Preto ...    22811920
# 9860044     Óculos De Sol Aviador Ray Ban Rb3025 001/51 Ta...     9860044
# 21739639    Notebook Asus FX502 IPS 1080p GTX 1060  SSD 25...    21739639
# 25575623    Conjunto Nature Glass Roupeiro 3 Portas Matic ...    25575623
# 20234849       Refrigerador Beer Maxx 250 216l Inox Metalfrio    20234849
# 25262943    Kit Máquina Wahl Detailer Bivolt + Wahl Legend...    25262943
# 13424480    Puff Multiuso 3 em 1 Puff Sofá ou Colchão Solt...    13424480
#
# [3124 rows x 2 columns]

# %% [markdown]
# #### Retrieving products categories

# %% [markdown]
# Let's write a function for crawling info for product ids:

# %%
def getProductInfo(prodId, info):
    requestUrl = AMERICANAS_BASEURL+"/produto/"+prodId
    productPage = BeautifulSoup( requests.get(requestUrl).text,"html5lib" )    
    
    vals = [prodId]
    for expr in info:
        try: vals += [expr[0](productPage)]
        except: vals += [expr[1]]
    vals += [datetime.datetime.utcnow()]
    
    return tuple(vals)
        
    
def getProductsInfo( productsIds, info, limit=None ):
    print("Retrieving products info...")
    productsInfoRecords = []
    productsFailed = []
    num_prods = prod_descs.shape[0]

    if (limit is not None) and (limit<num_prods):
        productsIds = productsIds[:limit]
        
    for i,prodId in enumerate( productsIds ):
        print("  ({}/{}) Crawling product".format(i+1,num_prods),prodId)
        try:
            productsInfoRecords += [getProductInfo(str(prodId),info)]
        except KeyboardInterrupt:
            raise(KeyboardInterrupt)
        except:
            print("  Failed retrieving info for",prodId) 
            productsFailed += [prodId]

    print("Done")   
    return (productsInfoRecords,productsFailed)

# %%
# info is organized as a tuple (expression,default)
info = [
    (lambda x: x.find("p",{'class':"sales-price"}).text, None), # promotional (or current) price
    (lambda x: x.find("strike",{'class':"regular-price"}).text,None), # previous (or regular) price
    (lambda x: '|'.join( i.text for i in x.find_all("span",{'class':"breadcrumb-title"}) ),None), # categories
    (lambda x: x.find("span",{'itemprop':"ratingValue"})['content'],None), # rating(num of stars)
    (lambda x: x.find("div",{'class':"rating-star-counter"})['content'],0) # num of ratings
]

# %%
pinfo = getProductsInfo(prod_descs['Product Id'],info, limit=10)
